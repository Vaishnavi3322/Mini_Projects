# %% [markdown]
# <a href="https://colab.research.google.com/github/Vaishnavi3322/Mini_Projects/blob/main/Mini_Projects.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## **Mini Project 1**

# %% [markdown]
# -----
# ### Subset Selection Problem
# -----
# ####**1. Problem Statement:**
# Find all the subsets from a set of numbers whose sum is zero.
#
# ####**Constraint: Subset size must be 5**
# Set={-12, -3, -6, 7, 2, -2, 6, 3, 9, -7, -5, -8, 1, 11, -9, -4}
#
# ---

# %% [markdown]
# ### **1.1 Library inclusion**

# %%
import random as r

# %% [markdown]
# ### **1.2 Parameter Setting**

# %%
Set         = set([-12, -3, -6, 7, 2, -2, 6, 3, 9, -7, -5, -8, 1, 11, -9, -4])
SetSize     = 5
ResultList  = set()    # Store Result List i.e. list of sets whose sum is zero
Iterations  = 1000    # Number of Inerations

# %% [markdown]
# ### **1.3 Start Program**

# %%
# Loop till number of Iterations
for i in range(Iterations):
    # Select number of elements from Set
    Chromosome = r.sample(Set,SetSize)
    
    # Sum the number of elements in the Chromosome
    if sum(Chromosome) == 0:
        ResultList.add(tuple(Chromosome))
# Out:
# <ipython-input-10-03544d6be9f3>:4: DeprecationWarning: Sampling from a set deprecated
# since Python 3.9 and will be removed in a subsequent version.
#   Chromosome = r.sample(Set,SetSize)

# %% [markdown]
# ### **1.4 Print the sets and total count**

# %%
# Print all the sets whose sum is zero
for r in ResultList:
	print (r)

# Print total sets
print ("\nTotal Sets: ", len(ResultList), "\n")
# Out:
# (1, 6, -7, 2, -2)
# (1, -7, 2, -2, 6)
# (-7, -3, 1, 3, 6)
# (-6, 11, -8, -4, 7)
# (-7, 11, -8, 3, 1)
# (1, -2, 7, -12, 6)
# (1, 6, -6, -8, 7)
# (-9, 9, -5, 2, 3)
# (7, -8, -3, -2, 6)
# (3, 6, -2, -9, 2)
# (-5, -9, 6, -3, 11)
# (-9, -5, 11, -3, 6)
# (1, -12, 11, -2, 2)
# (1, 7, -12, -5, 9)
# (-2, -3, 11, -8, 2)
# (11, -6, -9, -5, 9)
# (6, 7, -2, -7, -4)
# (7, 3, -7, 6, -9)
# (3, -8, -12, 11, 6)
# (-2, 7, -3, -5, 3)
# (-3, 1, 3, -12, 11)
# (-6, 1, 6, 3, -4)
# (-2, 7, 1, 3, -9)
# (6, -5, -4, 9, -6)
# (-4, 2, 11, -6, -3)
# (7, 6, -8, 1, -6)
# (-2, 1, 2, 11, -12)
# (-12, 2, 9, 7, -6)
# (-4, 11, -7, 2, -2)
# (-3, -4, 11, 1, -5)
# (-3, -6, 11, -5, 3)
# (-12, 7, -6, 9, 2)
#
# Total Sets:  32

# %% [markdown]
# ---
# ### **1.5 Complete Program**
# ---

# %%
#-------------------------------------------------------------
# Step 1: Library inclusion                             
#-------------------------------------------------------------
import random as r


#-------------------------------------------------------------
# Step 2: Parameter Setting
#-------------------------------------------------------------
Set         = set([-12, -3, -6, 7, 2, -2, 6, 3, 9, -7, -5, -8, 1, 11, -9, -4])
SetSize     = 5
ResultList  = set()    # Store Result List i.e. list of sets whose sum is zero
Iterations  = 1000   # Number of Inerations


#-------------------------------------------------------------
# Step3: Start Program
#-------------------------------------------------------------

# Loop till number of Iterations
for i in range(Iterations):
    # Select number of elements from Set
    Chromosome = r.sample(Set,SetSize)

    # Sum the number of elements in the Chromosome
    if sum(Chromosome) == 0:
        ResultList.add(tuple(Chromosome))

# Print all the sets whose sum is zero
for r in ResultList:
	print (r)

# Print total sets
print ("\nTotal Sets: ", len(ResultList))
# Out:
# (6, -6, -5, 9, -4)
# (-5, 3, 11, -2, -7)
# (-8, 9, -3, -4, 6)
# (-2, -6, 9, -3, 2)
# (2, 1, 6, -7, -2)
# (3, -8, 1, -7, 11)
# (11, -4, -7, 9, -9)
# (1, 6, -12, -2, 7)
# (-4, 7, -9, -3, 9)
# (-7, -4, 6, 2, 3)
# (-2, 1, 11, -7, -3)
# (-9, -3, -6, 11, 7)
# (1, -5, -6, 3, 7)
# (11, -12, 6, 3, -8)
# (-7, 9, 6, -6, -2)
# (6, 1, -6, 3, -4)
# (-7, -12, 11, 7, 1)
# (-6, 6, 7, -9, 2)
# (9, -5, -2, 6, -8)
# (-12, 6, -3, 2, 7)
# (3, -8, 11, -12, 6)
# (-12, 3, 2, 11, -4)
# (-8, 11, -7, 1, 3)
# (6, -7, 11, -12, 2)
# (-7, 6, -2, 2, 1)
# (9, -5, -2, -4, 2)
# (-3, -8, 11, -9, 9)
# (1, 7, -6, 3, -5)
# (3, -12, -9, 7, 11)
# (6, -12, -8, 11, 3)
# (9, 2, -9, 6, -8)
# (1, 7, -9, -2, 3)
# (7, 9, -8, -2, -6)
# (-2, -3, 6, 11, -12)
# (-5, 7, -7, 11, -6)
#
# Total Sets:  35
# <ipython-input-12-863105f7322f>:23: DeprecationWarning: Sampling from a set deprecated
# since Python 3.9 and will be removed in a subsequent version.
#   Chromosome = r.sample(Set,SetSize)

# %% [markdown]
# ---
# ### **1.6 Complete Program with sorting**
# ---

# %%
#-------------------------------------------------------------
# Step 1: Library inclusion                             
#-------------------------------------------------------------
import random as r


#-------------------------------------------------------------
# Step 2: Parameter Setting
#-------------------------------------------------------------
Set         = set([-12, -3, -6, 7, 2, -2, 6, 3, 9, -7, -5, -8, 1, 11, -9, -4])
SetSize     = 5
ResultList  = set()    # Store Result List i.e. list of sets whose sum is zero
Iterations  = 1000   # Number of Inerations


#-------------------------------------------------------------
# Step3: Start Program
#-------------------------------------------------------------

# Loop till number of Iterations
for i in range(Iterations):
    # Select number of elements from Set
    Chromosome = r.sample(Set,SetSize)
    Chromosome.sort()

    # Sum the number of elements in the Chromosome
    if sum(Chromosome) == 0:
        ResultList.add(tuple(Chromosome))

# Print all the sets whose sum is zero
for r in ResultList:
	print (r)

# Print total sets
print ("\nTotal Sets: ", len(ResultList))
# Out:
# (-12, -6, -2, 9, 11)
# (-9, -3, 2, 3, 7)
# (-9, -8, 2, 6, 9)
# (-8, -6, -4, 7, 11)
# (-7, -4, -3, 3, 11)
# (-8, -4, -3, 6, 9)
# (-8, -7, -3, 7, 11)
# (-7, -6, 1, 3, 9)
# (-12, -3, 1, 3, 11)
# (-4, -2, 1, 2, 3)
# (-6, -5, -3, 3, 11)
# (-6, -5, 2, 3, 6)
# (-6, -5, -2, 2, 11)
# (-9, -7, -2, 7, 11)
# (-5, -3, -2, 1, 9)
# (-8, -4, 2, 3, 7)
# (-8, -3, -2, 2, 11)
# (-9, -5, 1, 6, 7)
# (-7, -6, -3, 7, 9)
# (-12, -4, 3, 6, 7)
# (-7, -5, -4, 7, 9)
# (-12, -4, -2, 7, 11)
# (-8, -6, 2, 3, 9)
#
# Total Sets:  23
# <ipython-input-13-91cb451df7bd>:23: DeprecationWarning: Sampling from a set deprecated
# since Python 3.9 and will be removed in a subsequent version.
#   Chromosome = r.sample(Set,SetSize)

# %% [markdown]
# ---
# ####**2. Problem Statement:**
# Find all the subsets from a set of numbers whose sum is zero.
#
# ####**Constraint: Subset size must be 3 to 6 only**
# Set={-12, -3, -6, 7, 2, -2, 6, 3, 9, -7, -5, -8, 1, 11, -9, -4}
#
# ---

# %%
#-------------------------------------------------------------
# Step 1: Library inclusion                             
#-------------------------------------------------------------
import random as r


#-------------------------------------------------------------
# Step 2: Parameter Setting
#-------------------------------------------------------------
Set         = set([-12, -3, -6, 7, 2, -2, 6, 3, 9, -7, -5, -8, 1, 11, -9, -4])
SetLB       = 3
SetUB       = 6
ResultList  = set()    # Store Result List i.e. list of sets whose sum is zero
Iterations  = 1000   # Number of Inerations


#-------------------------------------------------------------
# Step3: Start Program
#-------------------------------------------------------------

# Loop till number of Iterations
for i in range(Iterations):
    # Select set size randomly
    SetSize = r.randint(SetLB,SetUB)
	
    # Select number of elements from Set
    Chromosome = r.sample(Set,SetSize)
    Chromosome.sort()

    # Sum the number of elements in the Chromosome
    if sum(Chromosome) == 0:
        ResultList.add(tuple(Chromosome))

# Print all the sets whose sum is zero
for r in ResultList:
	print (r)

# Print total sets
print ("\nTotal Sets: ", len(ResultList))
# Out:
# (-8, -3, 2, 9)
# (-3, -2, 2, 3)
# (-8, -4, 1, 11)
# (-9, -6, -4, 2, 6, 11)
# (-9, -7, 2, 3, 11)
# (-8, -6, 3, 11)
# (-7, -6, -5, 1, 6, 11)
# (-12, 3, 9)
# (-9, -8, 1, 2, 3, 11)
# (-8, -5, -4, 2, 6, 9)
# (-8, -6, -2, 7, 9)
# (-6, -3, -2, 11)
# (-6, -4, 1, 3, 6)
# (-7, -5, -4, 2, 3, 11)
# (-4, 1, 3)
# (-12, 1, 11)
# (-7, -2, 1, 2, 6)
# (-8, -3, 1, 3, 7)
# (-8, 2, 6)
# (-8, -5, -2, 6, 9)
# (-7, -4, 11)
# (-5, -4, -2, 1, 3, 7)
# (-9, -2, 11)
# (-6, -3, 9)
# (-9, -6, 6, 9)
# (-9, -4, -3, 1, 6, 9)
# (-5, -2, 7)
# (-7, -6, -3, 2, 3, 11)
# (-8, -5, -4, 1, 7, 9)
# (-7, -6, -3, 7, 9)
# (-12, -6, -2, 2, 7, 11)
# (-8, -7, 6, 9)
# (-5, -4, -3, 3, 9)
# (-9, -6, 2, 6, 7)
# (-7, 1, 6)
# (-12, -9, 3, 7, 11)
# (-12, -7, 1, 7, 11)
# (-7, -6, -5, 7, 11)
# (-7, -3, 3, 7)
# (-8, -3, 11)
# (-9, -3, -2, 3, 11)
# (-7, -5, -3, -2, 6, 11)
# (-6, -5, -2, 6, 7)
# (-7, -5, -3, 1, 3, 11)
# (-6, -5, -2, 1, 3, 9)
#
# Total Sets:  45
# <ipython-input-14-8bdee75e019c>:27: DeprecationWarning: Sampling from a set deprecated
# since Python 3.9 and will be removed in a subsequent version.
#   Chromosome = r.sample(Set,SetSize)

# %% [markdown]
# ## **Mini Project 2**

# %% [markdown]
#   ---
# # **ComboFinder**
# ---
# ####**Problem Statement:**
# Find all the list of products whose sum-of-price is between 290 and 310.
#
# ProductList = {p1:10, p2:15, p3:20, p4:25, p5:30, p6:35, p7:50}
#
# ---

# %% [markdown]
# ### **1 Library inclusion**

# %%
import random as r

# %% [markdown]
# ### **2 Parameter Setting**
# Read the productId-price file and convert to dictionary

# %%
ProductList = {'p1':10, 'p2':15, 'p3':20, 'p4':25, 'p5':30, 'p6':35, 'p7':50,
               'p8':40, 'p9':55, 'p10':60, 'p11':65, 'p12':75, 'p13':70,
               'p14':45}
LB          = 290
UB          = 310
ResultList  = set()   # Store Result List i.e. list of sets whose sum is between 90 and 210.
Iterations  = 1000    # Number of Inerations

# %% [markdown]
# ### **Single Run**

# %%
# Select combo size (i.e. number of products in a combo)
SetSize = r.randint(2, len(ProductList)-1)
print("Number of Product: ", SetSize)


# Select number of elements from Set
ComboList = r.sample(list(ProductList.keys()),SetSize)
print("Product List     : ", ComboList)


# Sum the products in ColboList
ComboSum = sum([ ProductList[i] for i in ComboList])
print("Sum of Product   : ", ComboSum)
# Out:
# Number of Product:  4
# Product List     :  ['p1', 'p13', 'p2', 'p10']
# Sum of Product   :  155

# %% [markdown]
# ### **3 Start Program**

# %%
# Loop till number of Iterations
ResultList  = set()

for i in range(Iterations):

    # Select combo size (i.e. number of products in a combo)
    SetSize = r.randint(2, len(ProductList)-1)

    # Select number of elements from Set
    ComboList = r.sample(list(ProductList.keys()),SetSize)

    # Sum the products in ColboList
    ComboSum = sum([ ProductList[i] for i in ComboList])
    
    # Check the Sum Between LB and UB
    if ComboSum>= LB and ComboSum<= UB:
      ResultList.add(tuple(ComboList))

print("Done")
# Out:
# Done

# %% [markdown]
# ### **4 Print the comboLists and total count**

# %%
# Print all the sets whose sum is between LB and UB
for r in ResultList:
	print (r)

# Print total sets
print ("\nTotal Sets: ", len(ResultList), "\n")
# Out:
# ('p8', 'p4', 'p7', 'p13', 'p1', 'p14', 'p10')
# ('p11', 'p10', 'p14', 'p4', 'p7', 'p5', 'p2')
# ('p14', 'p5', 'p8', 'p10', 'p11', 'p9')
# ('p9', 'p1', 'p3', 'p12', 'p13', 'p4', 'p6')
# ('p11', 'p13', 'p10', 'p8', 'p2', 'p7')
# ('p12', 'p2', 'p9', 'p8', 'p6', 'p11', 'p1')
# ('p5', 'p10', 'p11', 'p13', 'p7', 'p3')
# ('p5', 'p14', 'p3', 'p13', 'p12', 'p1', 'p7')
# ('p9', 'p10', 'p11', 'p14', 'p6', 'p5')
# ('p13', 'p10', 'p12', 'p8', 'p9')
# ('p2', 'p3', 'p11', 'p1', 'p8', 'p6', 'p10', 'p9')
# ('p8', 'p12', 'p9', 'p10', 'p14', 'p6')
# ('p10', 'p11', 'p3', 'p13', 'p4', 'p9')
# ('p9', 'p14', 'p10', 'p6', 'p2', 'p12', 'p1')
# ('p14', 'p4', 'p9', 'p10', 'p6', 'p3', 'p7')
# ('p1', 'p4', 'p13', 'p5', 'p8', 'p10', 'p2', 'p14')
# ('p3', 'p1', 'p14', 'p6', 'p13', 'p11', 'p5', 'p4')
# ('p13', 'p6', 'p1', 'p5', 'p14', 'p8', 'p2', 'p11')
# ('p9', 'p1', 'p13', 'p5', 'p3', 'p8', 'p12')
# ('p4', 'p11', 'p10', 'p12', 'p7', 'p6')
# ('p6', 'p14', 'p3', 'p7', 'p10', 'p2', 'p11')
# ('p11', 'p4', 'p8', 'p12', 'p3', 'p13', 'p1')
# ('p6', 'p8', 'p7', 'p14', 'p4', 'p1', 'p13', 'p3')
# ('p11', 'p1', 'p9', 'p10', 'p2', 'p6', 'p7')
# ('p1', 'p9', 'p13', 'p11', 'p10', 'p5')
# ('p1', 'p13', 'p11', 'p12', 'p9', 'p5')
# ('p2', 'p5', 'p7', 'p11', 'p6', 'p14', 'p9')
# ('p12', 'p11', 'p5', 'p14', 'p2', 'p10')
# ('p6', 'p1', 'p7', 'p8', 'p3', 'p10', 'p14', 'p2', 'p5')
# ('p11', 'p14', 'p9', 'p3', 'p8', 'p7', 'p2')
# ('p4', 'p7', 'p10', 'p1', 'p11', 'p2', 'p3', 'p9')
# ('p10', 'p14', 'p8', 'p5', 'p7', 'p1', 'p11')
# ('p1', 'p4', 'p7', 'p11', 'p13', 'p8', 'p6', 'p2')
# ('p14', 'p10', 'p9', 'p6', 'p13', 'p5')
# ('p14', 'p13', 'p11', 'p6', 'p1', 'p2', 'p3', 'p8')
# ('p10', 'p5', 'p8', 'p11', 'p1', 'p13', 'p6')
# ('p1', 'p13', 'p5', 'p12', 'p2', 'p4', 'p11')
# ('p12', 'p14', 'p7', 'p13', 'p2', 'p9')
# ('p1', 'p7', 'p9', 'p11', 'p5', 'p13', 'p4')
# ('p3', 'p10', 'p13', 'p12', 'p14', 'p4')
# ('p4', 'p11', 'p6', 'p10', 'p1', 'p9', 'p8')
# ('p8', 'p13', 'p2', 'p5', 'p12', 'p11')
# ('p10', 'p12', 'p7', 'p14', 'p3', 'p9')
# ('p14', 'p11', 'p9', 'p13', 'p12')
# ('p11', 'p9', 'p3', 'p4', 'p14', 'p6', 'p10')
# ('p13', 'p8', 'p9', 'p7', 'p11', 'p4')
# ('p5', 'p12', 'p13', 'p7', 'p1', 'p2', 'p9')
# ('p9', 'p12', 'p5', 'p10', 'p11', 'p2')
# ('p4', 'p2', 'p3', 'p13', 'p6', 'p9', 'p12')
#
# Total Sets:  49

# %% [markdown]
# ---
# ### **5 Complete Program with sorting**
# ---

# %%
#-------------------------------------------------------------
# Step 1: Library inclusion                             
#-------------------------------------------------------------
import random as r


#-------------------------------------------------------------
# Step 2: Parameter Setting
#-------------------------------------------------------------
ProductList = {'p1':10, 'p2':15, 'p3':20, 'p4':25, 'p5':30, 'p6':35, 'p7':50,
               'p8':40, 'p9':55, 'p10':60, 'p11':65, 'p12':75, 'p13':70,
               'p14':45}
LB          = 290
UB          = 310
ResultList  = set()   # Store Result List i.e. list of sets whose sum is between 90 and 210.
Iterations  = 1000    # Number of Inerations


#-------------------------------------------------------------
# Step3: Start Program
#-------------------------------------------------------------
for i in range(Iterations):

    # Select combo size (i.e. number of products in a combo)
    SetSize = r.randint(2, len(ProductList)-1)

    # Select number of elements from Set
    ComboList = r.sample(list(ProductList.keys()),SetSize)
    ComboList.sort()

    # Sum the products in ColboList
    ComboSum = sum([ ProductList[i] for i in ComboList])

    # Check the Sum Between LB and UB
    if ComboSum>= LB and ComboSum<= UB:
      ResultList.add(tuple(ComboList))


# Print all the sets whose sum is between LB and UB
for r in ResultList:
	print (r)

# Print total sets
print ("\nTotal Sets: ", len(ResultList), "\n")
# Out:
# ('p10', 'p12', 'p14', 'p3', 'p4', 'p6', 'p8')
# ('p10', 'p13', 'p4', 'p5', 'p7', 'p9')
# ('p1', 'p11', 'p12', 'p3', 'p4', 'p5', 'p6', 'p8')
# ('p10', 'p11', 'p13', 'p14', 'p2', 'p3', 'p5')
# ('p1', 'p12', 'p14', 'p2', 'p3', 'p4', 'p5', 'p6', 'p9')
# ('p1', 'p10', 'p11', 'p12', 'p14', 'p9')
# ('p11', 'p14', 'p2', 'p3', 'p5', 'p6', 'p7', 'p8')
# ('p11', 'p14', 'p2', 'p3', 'p4', 'p5', 'p7', 'p9')
# ('p10', 'p11', 'p12', 'p2', 'p3', 'p9')
# ('p1', 'p10', 'p11', 'p14', 'p5', 'p6', 'p7')
# ('p1', 'p10', 'p13', 'p14', 'p2', 'p3', 'p4', 'p9')
# ('p1', 'p10', 'p2', 'p3', 'p4', 'p6', 'p7', 'p8', 'p9')
# ('p1', 'p11', 'p3', 'p4', 'p5', 'p7', 'p8', 'p9')
# ('p12', 'p13', 'p14', 'p2', 'p3', 'p4', 'p7')
# ('p10', 'p12', 'p14', 'p2', 'p4', 'p5', 'p9')
# ('p10', 'p13', 'p14', 'p4', 'p7', 'p9')
# ('p1', 'p10', 'p11', 'p14', 'p2', 'p3', 'p7', 'p8')
# ('p10', 'p2', 'p3', 'p4', 'p6', 'p7', 'p8', 'p9')
# ('p1', 'p10', 'p14', 'p2', 'p3', 'p4', 'p5', 'p7', 'p9')
# ('p11', 'p13', 'p3', 'p4', 'p5', 'p6', 'p7')
# ('p11', 'p12', 'p13', 'p4', 'p6', 'p8')
# ('p1', 'p12', 'p13', 'p14', 'p4', 'p6', 'p7')
# ('p10', 'p11', 'p12', 'p4', 'p5', 'p6')
# ('p1', 'p11', 'p13', 'p2', 'p4', 'p5', 'p6', 'p8')
# ('p13', 'p2', 'p3', 'p4', 'p5', 'p6', 'p8', 'p9')
# ('p1', 'p10', 'p12', 'p13', 'p2', 'p4', 'p8')
# ('p10', 'p11', 'p14', 'p2', 'p5', 'p8', 'p9')
# ('p10', 'p11', 'p13', 'p14', 'p2', 'p3', 'p6')
# ('p1', 'p12', 'p13', 'p14', 'p2', 'p5', 'p9')
# ('p10', 'p11', 'p12', 'p14', 'p4', 'p5')
# ('p1', 'p10', 'p11', 'p12', 'p2', 'p4', 'p9')
# ('p10', 'p13', 'p5', 'p7', 'p8', 'p9')
# ('p1', 'p10', 'p12', 'p13', 'p14', 'p2', 'p6')
# ('p10', 'p12', 'p13', 'p14', 'p2', 'p3', 'p4')
# ('p1', 'p10', 'p11', 'p13', 'p2', 'p5', 'p9')
# ('p13', 'p2', 'p5', 'p6', 'p7', 'p8', 'p9')
# ('p10', 'p12', 'p4', 'p6', 'p7', 'p9')
# ('p10', 'p11', 'p12', 'p14', 'p2', 'p7')
# ('p1', 'p11', 'p2', 'p3', 'p4', 'p5', 'p7', 'p8', 'p9')
# ('p10', 'p11', 'p3', 'p7', 'p8', 'p9')
# ('p11', 'p13', 'p5', 'p6', 'p7', 'p9')
# ('p11', 'p12', 'p14', 'p2', 'p3', 'p5', 'p7')
# ('p1', 'p13', 'p14', 'p2', 'p3', 'p4', 'p5', 'p6', 'p8')
# ('p1', 'p11', 'p13', 'p2', 'p3', 'p5', 'p6', 'p7')
# ('p10', 'p11', 'p14', 'p3', 'p4', 'p8', 'p9')
# ('p1', 'p11', 'p4', 'p5', 'p6', 'p7', 'p8', 'p9')
# ('p10', 'p13', 'p2', 'p4', 'p6', 'p8', 'p9')
# ('p11', 'p13', 'p14', 'p3', 'p7', 'p8')
#
# Total Sets:  48

# %% [markdown]
# ## **Mini Project 3**

# %% [markdown]
# -----
# # **Text File Conversion**
# -----
# #### Compare the Performance (time taken) of C, C++, Java. R and Python programs for :
# Convert 200MB, 400MB, 600MB, 800MB and 1000MB text files to upper case.
# File = ['C', 'C++', 'Java', 'R', 'Python']
# Size = ['200MB','400MB', '600MB', '800MB', '1000MB']
# Time_taken = [{12 15 18 20 25}, {20 25 30 35 40}, {34 36 40 45 53}, {45 50 55 60 75}, {55 60 70 80 100}]
#
# -----

# %%
import seaborn as sns
import pandas as pd
import numpy as np
df = pd.DataFrame({'File Size': ['200MB','400MB', '600MB', '800MB', '1000MB'],
                   'C' : [12, 20, 34, 45, 55],
                   'C++': [15, 25, 36, 50, 60],
                   'Java': [18, 30, 40, 55, 70],
                   'R': [20, 35, 45, 60, 80],
                   'Python': [25, 40, 53, 75, 100]})
df
# Out:
#   File Size   C  C++  Java   R  Python
# 0     200MB  12   15    18  20      25
# 1     400MB  20   25    30  35      40
# 2     600MB  34   36    40  45      53
# 3     800MB  45   50    55  60      75
# 4    1000MB  55   60    70  80     100

# %%
x  = [1, 2, 3, 4, 5]
y1 = [12, 20, 34, 45, 55]
y2 = [15, 25, 36, 50, 60]
y3 = [18, 30, 40, 55, 70]
y4 = [20, 35, 45, 60, 80]
y5 = [25, 40, 53, 75, 100]
graph = sns.lineplot(x=x, y=y1, label='C', linewidth=2)
sns.lineplot(x = x, y = y2, label='C++', linewidth=2)
sns.lineplot(x = x, y = y3, label='Java', linewidth=2)
sns.lineplot(x = x, y = y4, label='R', linewidth=2)
sns.lineplot(x = x, y = y5, label='Python', linewidth=2)
graph.set_xlabel('File Size(GB)')
graph.set_ylabel('Time Taken(in sec)')
graph.set_title('Performance Comparision of Different Programming Languages')
# Out:
# Text(0.5, 1.0, 'Performance Comparision of Different Programming Languages')

# %% [markdown]
# -----
# ## **Mini Project 4**
# -----
# Marks Adding
# ![download (1)_.png](data:image/png;base64,...)

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
df = pd.read_csv('/content/Mini Project - Marks Adding.csv')

# %%
df.head()
# Out:
#     Roll Num  Marks
# 0  102003542      1
# 1  102003640      1
# 2  102003725      1
# 3  102003307      1
# 4  102003458      1

# %%
print(df.count())
print(df.isnull().sum())
# Out:
# Roll Num    1836
# Marks       1836
# dtype: int64
# Roll Num    0
# Marks       0
# dtype: int64

# %%
duplicate_rows_df = df[df.duplicated()]
print("number of duplicate rows: ", duplicate_rows_df.shape)
# Out:
# number of duplicate rows:  (1373, 2)

# %%
agg_functions = {'Marks': 'first', 'Marks':'sum'}
df1 = df.groupby(df['Roll Num']).aggregate(agg_functions)
print(df1)
# Out:
#            Marks
# Roll Num
# 102003001      3
# 102003002      5
# 102003017      5
# 102003018      5
# 102003029      5
# ...          ...
# 102196010      4
# 102197016      5
# 102197018      4
# 102197019      5
# 102197021      5
#
# [400 rows x 1 columns]
